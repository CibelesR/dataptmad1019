# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax[0].plot(x,y, '-.', "purple")
ax[1].plot(x,z, "turquoise", '-.')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.plot(x,y,color="orange", lw=3, ls='--')
ax2.plot(x,z,color="black", lw=3, ls='-')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, (ax3, ax4) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax3.plot(x, y, linewidth = 3)
ax4.plot(x, z, '.', linewidth = 0.5)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
axes[0].plot(x, y, linewidth = 3)
axes[1].plot(x, z, '.', linewidth = 0.5)

axes[0].set_xlabel('Ey I just met you')
axes[0].set_ylabel('And this is crazy')
axes[1].set_xlabel('But here is my number')
axes[1].set_ylabel('So call me maybe')
# Out:
# Text(0, 0.5, 'So call me maybe')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
axes[0].plot(x, y, linewidth = 3)
axes[1].plot(x, z, '.', linewidth = 0.5)

axes[0].set_yscale('log')
axes[0].set_xscale('linear')
axes[1].set_yscale('linear')
axes[1].set_xscale('log')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df_vehicles = pd.read_csv('vehicles.csv')
x = df_vehicles['Combined MPG']
y = df_vehicles['Highway MPG']
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))
plt.scatter(x, y, linewidth = 0.1)
plt.show()

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 10))
ax.boxplot(df_vehicles['CO2 Emission Grams/Mile'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12be1e890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12be111d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12be113d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12be26d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12be1e210>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))
x = df_vehicles['Fuel Barrels/Year']

plt.hist(x, bins=50)
# Out:
# (array([6.000e+01, 3.000e+00, 2.000e+00, 8.000e+00, 8.000e+00, 1.000e+01,
#         2.500e+01, 4.200e+01, 1.600e+02, 1.370e+02, 4.210e+02, 7.050e+02,
#         1.754e+03, 2.305e+03, 1.580e+03, 4.020e+03, 3.167e+03, 3.092e+03,
#         3.231e+03, 3.529e+03, 2.308e+03, 2.305e+03, 6.500e+01, 2.348e+03,
#         1.940e+03, 8.600e+01, 1.245e+03, 3.000e+01, 5.000e+00, 7.300e+02,
#         0.000e+00, 4.390e+02, 0.000e+00, 0.000e+00, 1.300e+02, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.600e+01, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 2.100e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 5.000e+00]),
#  array([ 0.06      ,  1.00054286,  1.94108571,  2.88162857,  3.82217143,
#          4.76271429,  5.70325714,  6.6438    ,  7.58434286,  8.52488571,
#          9.46542857, 10.40597143, 11.34651429, 12.28705714, 13.2276    ,
#         14.16814286, 15.10868571, 16.04922857, 16.98977143, 17.93031429,
# ...

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

x = df_vehicles['Fuel Type']
y = df_vehicles['City MPG']

plt.bar(x,y)
plt.show()
